# %%
import os
import shutil

# %%
ls datasets/varos_data
# Out:
# testA/     testB/  testD.zip    trainA/  trainD/
# test_air/  testD/  test_water/  trainB/

# %%
mkdir datasets/varos_data/testB

# %%
source1 = 'datasets/varos_data/testA/'
source2 = "/home/shamba/Desktop/2021-08-17_SEQ1/2021-08-17_SEQ1/vehicle0/cam0/A"
destination = 'datasets/varos_data/testB/'

# %%
# gather all files
allfiles = os.listdir(source1)
 
# iterate on all files to move them to destination folder
for f in allfiles:
    print(f)
    f = f.replace('B', "A")
    print(f)
    src_path = os.path.join(source2, f)
    dst_path = os.path.join(destination, f)
    shutil.copy(src_path, dst_path)
# Out:
# seq01_veh0_camM0_B-00000389.png
# seq01_veh0_camM0_A-00000389.png
# seq01_veh0_camM0_B-00002258.png
# seq01_veh0_camM0_A-00002258.png
# seq01_veh0_camM0_B-00001825.png
# seq01_veh0_camM0_A-00001825.png
# seq01_veh0_camM0_B-00000281.png
# seq01_veh0_camM0_A-00000281.png
# seq01_veh0_camM0_B-00000064.png
# seq01_veh0_camM0_A-00000064.png
# seq01_veh0_camM0_B-00003275.png
# seq01_veh0_camM0_A-00003275.png
# seq01_veh0_camM0_B-00002077.png
# seq01_veh0_camM0_A-00002077.png
# seq01_veh0_camM0_B-00002863.png
# seq01_veh0_camM0_A-00002863.png
# seq01_veh0_camM0_B-00001423.png
# seq01_veh0_camM0_A-00001423.png
# seq01_veh0_camM0_B-00001457.png
# seq01_veh0_camM0_A-00001457.png
# seq01_veh0_camM0_B-00001976.png
# seq01_veh0_camM0_A-00001976.png
# seq01_veh0_camM0_B-00000373.png
# seq01_veh0_camM0_A-00000373.png
# seq01_veh0_camM0_B-00003076.png
# seq01_veh0_camM0_A-00003076.png
# seq01_veh0_camM0_B-00001593.png
# seq01_veh0_camM0_A-00001593.png
# seq01_veh0_camM0_B-00000540.png
# ...

# %%
# pip install pytorch-fid

# %%
pwd
# Out:
# '/home/shamba/Msc Thesis - NTNU/contrastive-unpaired-translation'

# %%
ls datasets/varos_data
# Out:
# testA/  test_air/  testD/  testD.zip  test_water/  trainA/  trainB/  trainD/

# %%
# !python3 -m pytorch_fid datasets/varos_data/testA/ datasets/varos_data/test_air/
# Out:
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:28<00:00,  7.23s/it]
# FID:  -9.368820485633478e-05

# %%
ls /home/shamba/Desktop/2021-08-17_SEQ1/2021-08-17_SEQ1/vehicle0/cam0/D
# Out:
# seq01_veh0_camM0_D-00000000.png*  seq01_veh0_camM0_D-00002358.png*
# seq01_veh0_camM0_D-00000001.png*  seq01_veh0_camM0_D-00002359.png*
# seq01_veh0_camM0_D-00000002.png*  seq01_veh0_camM0_D-00002360.png*
# seq01_veh0_camM0_D-00000003.png*  seq01_veh0_camM0_D-00002361.png*
# seq01_veh0_camM0_D-00000004.png*  seq01_veh0_camM0_D-00002362.png*
# seq01_veh0_camM0_D-00000005.png*  seq01_veh0_camM0_D-00002363.png*
# seq01_veh0_camM0_D-00000006.png*  seq01_veh0_camM0_D-00002364.png*
# seq01_veh0_camM0_D-00000007.png*  seq01_veh0_camM0_D-00002365.png*
# seq01_veh0_camM0_D-00000008.png*  seq01_veh0_camM0_D-00002366.png*
# seq01_veh0_camM0_D-00000009.png*  seq01_veh0_camM0_D-00002367.png*
# seq01_veh0_camM0_D-00000010.png*  seq01_veh0_camM0_D-00002368.png*
# seq01_veh0_camM0_D-00000011.png*  seq01_veh0_camM0_D-00002369.png*
# seq01_veh0_camM0_D-00000012.png*  seq01_veh0_camM0_D-00002370.png*
# seq01_veh0_camM0_D-00000013.png*  seq01_veh0_camM0_D-00002371.png*
# ...
